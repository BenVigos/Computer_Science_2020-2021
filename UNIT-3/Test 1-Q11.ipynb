# %% [markdown]
# <a href="https://colab.research.google.com/github/BenVigos/Computer_Science_2020-2021/blob/master/UNIT-3/Test%201-Q11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#check_inputs


num_inputs = [1, 2, 2, 1]

num_inputs_2 = [2, 2, 2, 2]

source = [4, 1, 3, 1, 2, 1]
strengths = [-0.1, 0.5, -0.4, 0.3, -0.4, 0.2]

# %%
def check_inputs(num_inputs, source, strengths):
  total_neurons = 0
  for neuron in num_inputs:
    total_neurons += neuron
  print(total_neurons)
  return total_neurons== len(source) and total_neurons== len(strengths)


print(check_inputs(num_inputs, source, strengths))
print("")
print(check_inputs(num_inputs_2, source, strengths))
# Out:
# 6
# True
#
# 8
# False

# %% [markdown]
# ![Screenshot 2021-02-28 at 20.23.19.png](data:image/png;base64,...)

# %% [markdown]
# | iteration | check_input() | start_idx | n | end_idx | out   | k | temp | cur_output[] | output                         |
# |------------|---------------|-----------|---|---------|-------|---|------|--------------|--------------------------------|
# | 0          | True          | 0         |   |         |       |   |      |              |                                |
# | 1          |               |           | 0 | 1       | 0.0   |   |      |              |                                |
# | 2          |               | 1         |   |         |       |   |      | [0]=0.0      | Output of neuron id 1 is 0.0   |
# | 3          |               |           | 1 | 3       | 0.0   |   |      |              |                                |
# | 4          |               |           |   |         | -0.05 | 1 | 0    |              |                                |
# | 5          |               |           |   |         | -0.13 | 2 | 2    |              |                                |
# | 6          |               | 3         |   |         |       |   |      | [1]=-0.13    | Output of neuron id 2 is -0.13 |
# | 7          |               |           | 2 | 5       | 0.0   |   |      |              |                                |
# | 8          |               |           |   |         | -0.05 | 3 | 0    |              |                                |
# | 9          |               |           |   |         | 0.05  | 4 | 1    |              |                                |
# | 10         |               | 5         |   |         |       |   |      | [2]=0.05     | Output of neuron id 3 is 0.05  |
# | 11         |               |           | 3 | 6       | 0.0   |   |      |              |                                |
# | 12         |               | 6         |   |         |       |   |      | [3]=0.0      | Output of neuron id 4 is 0.0   |
